# %%
import pandas as pd

# %%
titanic_data = pd.read_csv("./data/tested.csv")
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
titanic_data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
col_names = titanic_data.columns
col_names
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
col_names_new = ['Id', 'Survived', 'Passenger Class', 'Full Name', 'Gender', 'Age', 'SibSp',
       'Parch', 'Ticket Number', 'Fare', 'Cabin', 'Station']

# %%
titanic_data = pd.read_csv("./data/tested.csv",names = col_names_new,skiprows=[0])
titanic_data
# Out:
#        Id  Survived  Passenger Class  \
# 0     892         0                3
# 1     893         1                3
# 2     894         0                2
# 3     895         0                3
# 4     896         1                3
# ..    ...       ...              ...
# 413  1305         0                3
# 414  1306         1                1
# 415  1307         0                3
# 416  1308         0                3
# 417  1309         0                3
#
#                                         Full Name  Gender   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
titanic_data = pd.read_csv("./data/tested.csv",skiprows=[0],header=None)
titanic_data
# Out:
#        0   1   2                                             3       4     5   \
# 0     892   0   3                              Kelly, Mr. James    male  34.5
# 1     893   1   3              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2     894   0   2                     Myles, Mr. Thomas Francis    male  62.0
# 3     895   0   3                              Wirz, Mr. Albert    male  27.0
# 4     896   1   3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..    ...  ..  ..                                           ...     ...   ...
# 413  1305   0   3                            Spector, Mr. Woolf    male   NaN
# 414  1306   1   1                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415  1307   0   3                  Saether, Mr. Simon Sivertsen    male  38.5
# 416  1308   0   3                           Ware, Mr. Frederick    male   NaN
# 417  1309   0   3                      Peter, Master. Michael J    male   NaN
#
# ...

# %%
dict_fruit={
    "Mango":pd.Series([4,5,6,3,1],index = [0,1,2,3,4]),
    "Apple":pd.Series([5,4,3,0,2],index = [0,1,2,3,4]),
    "Banana":pd.Series([2,3,5,2,7],index = [0,1,2,3,5])
}
df_fruit = pd.DataFrame(dict)
# df_fruit.to_csv("./data/fruit.csv")
# df_fruit.to_csv("./data/fruit.csv",index=False)
# df_fruit.to_csv("./data/fruit.csv",index = False, sep = ";")
df_fruit.to_csv("./data/fruit.csv",)

# %%
import json

# %%
data = '''[
    {"name": "Tuấn Anh", "gender": "Female", "birthday": "1990-05-15", "score": 85},
    {"name": "Hải", "gender": "Male", "birthday": "1988-11-20", "score": 92},
    {"name": "Charlie", "gender": "Male", "birthday": "1995-02-10", "score": 78},
    {"name": "David", "gender": "Male", "birthday": "1992-08-05", "score": 89}
]'''
# print(data)
json_object = json.loads(data)
json_object
# Out:
# [{'name': 'Tuấn Anh',
#   'gender': 'Female',
#   'birthday': '1990-05-15',
#   'score': 85},
#  {'name': 'Hải', 'gender': 'Male', 'birthday': '1988-11-20', 'score': 92},
#  {'name': 'Charlie', 'gender': 'Male', 'birthday': '1995-02-10', 'score': 78},
#  {'name': 'David', 'gender': 'Male', 'birthday': '1992-08-05', 'score': 89}]

# %%
# Define the output file path
output_file = "./data/data.json"

# Save the JSON data to a file
with open(output_file, "w", encoding="utf-8") as json_file:
    json.dump(json_object, json_file, ensure_ascii=False)

# %%
data_2 = {"name": "Tuấn Anh", "gender": "Female", "birthday": "1990-05-15", "score": 85}
output_file = "./data/data.json"

# Save the JSON data to a file
with open(output_file, "w", encoding="utf-8") as json_file:
    json.dump(data_2, json_file, ensure_ascii=False)
